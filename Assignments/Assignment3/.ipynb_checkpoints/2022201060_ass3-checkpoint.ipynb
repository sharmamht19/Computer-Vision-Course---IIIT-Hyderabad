# %%
from pytube import YouTube
import os
import cv2
import time

# %% [markdown]
# # Q1: Face detection and association-based tracking

# %% [markdown]
# ## 1.1 - Data preparation.
# We will implement face detection and tracking on a famous scene from the movie Forrest Gump. To prepare the dataset, please download the video clip from https://www.youtube.com/ watch?v=bSMxl1V8FSg (the mp4 at 480p resolution) and burst the first 30 seconds into frames (you should get about 719-720 frames).

# %%
def download_video(video_url, output_dir):
    yt = YouTube(video_url)
    video = yt.streams.filter(file_extension='mp4', resolution='480p').first()
    video_path = video.download(output_dir)

    # Check if the video was downloaded successfully
    if os.path.exists(video_path):
        new_file_path = os.path.join(output_dir, "input_video.mp4")
        os.rename(video_path, new_file_path)
        print("Video downloaded successfully.")
        return new_file_path
    else:
        print("Error downloading video.")
        return None

def extract_frames(video_path, output_dir, duration=30):
    os.makedirs(output_dir, exist_ok=True)

    # Extract frames from the video
    ffmpeg_command = f"ffmpeg -i {video_path} -vf fps=24/1 -t {duration} {output_dir}/frame_%03d.png"
    result = os.system(ffmpeg_command)

    if result == 0:
        print("Frames extracted successfully.")
        return True
    else:
        print("Error extracting frames.")
        return False

# %%
video_url = "https://www.youtube.com/watch?v=bSMxl1V8FSg"
video_output_dir = "input"
frames_output_dir = "input_frames"
duration = 30 # Duration of frames to extract (in seconds)

video_path = download_video(video_url, video_output_dir)
if video_path:
    extract_frames(video_path, frames_output_dir, duration)
# Out:
# Video downloaded successfully.
# ffmpeg version 6.1.1 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.1.0.2.5)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.1.1_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'input/input_video.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     creation_time   : 2023-02-02T19:46:41.000000Z
#   Duration: 00:02:22.10, start: 0.000000, bitrate: 974 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 854x480 [SAR 1:1 DAR 427:240], 38 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       creation_time   : 2023-02-02T19:46:41.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x1288f8000] [swscaler @ 0x128908000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1288f8000] [swscaler @ 0x128918000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1288f8000] [swscaler @ 0x128928000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1288f8000] [swscaler @ 0x128938000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1288f8000] [swscaler @ 0x128948000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1288f8000] [swscaler @ 0x128958000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1288f8000] [swscaler @ 0x128968000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1288f8000] [swscaler @ 0x128978000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1288f8000] [swscaler @ 0x128988000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x118008000] [swscaler @ 0x1288f8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x118008000] [swscaler @ 0x128908000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x118008000] [swscaler @ 0x128918000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x118008000] [swscaler @ 0x128928000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x118008000] [swscaler @ 0x128938000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x118008000] [swscaler @ 0x128948000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x118008000] [swscaler @ 0x128958000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x118008000] [swscaler @ 0x128968000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x118008000] [swscaler @ 0x128978000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128978000] [swscaler @ 0x118008000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128978000] [swscaler @ 0x118018000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128978000] [swscaler @ 0x118028000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128978000] [swscaler @ 0x118260000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128978000] [swscaler @ 0x118270000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128978000] [swscaler @ 0x118280000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128978000] [swscaler @ 0x118290000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128978000] [swscaler @ 0x1182a0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128978000] [swscaler @ 0x1182b0000] No accelerated colorspace conversion found from yuv420p to rgb24.
#     Last message repeated 1 times
# [swscaler @ 0x128978000] [swscaler @ 0x118008000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128978000] [swscaler @ 0x118018000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128978000] [swscaler @ 0x118028000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128978000] [swscaler @ 0x118260000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128978000] [swscaler @ 0x118270000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128978000] [swscaler @ 0x118280000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128978000] [swscaler @ 0x118290000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128978000] [swscaler @ 0x1182a0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'input_frames/frame_%03d.png':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     encoder         : Lavf60.16.100
#   Stream #0:0(und): Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 854x480 [SAR 1:1 DAR 427:240], q=2-31, 200 kb/s, 24 fps, 24 tbn (default)
#     Metadata:
#       creation_time   : 2023-02-02T19:46:41.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 png
# frame=  642 fps=179 q=-0.0 size=N/A time=00:00:26.75 bitrate=N/A speed=7.45x
# Frames extracted successfully.
# [out#0/image2 @ 0x6000031f4540] video:389493kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# frame=  720 fps=177 q=-0.0 Lsize=N/A time=00:00:29.95 bitrate=N/A speed=7.38x

# %% [markdown]
# ## 1.2 - Face detection.
# Use the Viola-Jones Haar cascades based face detector from OpenCV to detect faces in each frame. How long does it take to process each frame? Identify some key factors of the algorithm that could change the time.
# Hint: you may need to look within the xml config file.

# %%
def detect_faces_and_save_video(frames_folder, output_folder, output_video_name):
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')


    frame_path = f'{frames_folder}/frame_001.png'
    first_frame = cv2.imread(frame_path)
    height, width, _ = first_frame.shape

    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    output_video_path = os.path.join(output_folder, output_video_name)
    out = cv2.VideoWriter(output_video_path, fourcc, 24.0, (width, height))

    total_processing_time = 0
    for i in range(1, 721):  
    
        frame = cv2.imread(f'{frames_folder}/frame_{i:03d}.png')
        
        gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        
        start_time = time.time()
        faces = face_cascade.detectMultiScale(gray_frame, scaleFactor=1.3, minNeighbors=8, minSize=(15, 15))
        end_time = time.time()
        
        processing_time = end_time - start_time
        total_processing_time += processing_time
        
        for (x, y, w, h) in faces:
            cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)
        out.write(frame)
        print(f"Frame {i}: Processing time = {processing_time:.2f} seconds")

    out.release()
    cv2.destroyAllWindows()

    print(f"Total processing time for all frames: {total_processing_time:.2f} seconds")

# %%
detect_faces_and_save_video("input_frames", "output", "output_video.mp4")
# Out:
# Frame 1: Processing time = 0.02 seconds
# Frame 2: Processing time = 0.01 seconds
# Frame 3: Processing time = 0.01 seconds
# Frame 4: Processing time = 0.01 seconds
# Frame 5: Processing time = 0.01 seconds
# Frame 6: Processing time = 0.01 seconds
# Frame 7: Processing time = 0.01 seconds
# Frame 8: Processing time = 0.01 seconds
# Frame 9: Processing time = 0.01 seconds
# Frame 10: Processing time = 0.01 seconds
# Frame 11: Processing time = 0.01 seconds
# Frame 12: Processing time = 0.01 seconds
# Frame 13: Processing time = 0.01 seconds
# Frame 14: Processing time = 0.01 seconds
# Frame 15: Processing time = 0.01 seconds
# Frame 16: Processing time = 0.01 seconds
# Frame 17: Processing time = 0.01 seconds
# Frame 18: Processing time = 0.01 seconds
# Frame 19: Processing time = 0.01 seconds
# Frame 20: Processing time = 0.01 seconds
# Frame 21: Processing time = 0.01 seconds
# Frame 22: Processing time = 0.01 seconds
# Frame 23: Processing time = 0.01 seconds
# Frame 24: Processing time = 0.01 seconds
# Frame 25: Processing time = 0.01 seconds
# Frame 26: Processing time = 0.01 seconds
# Frame 27: Processing time = 0.01 seconds
# Frame 28: Processing time = 0.01 seconds
# Frame 29: Processing time = 0.01 seconds
# Frame 30: Processing time = 0.01 seconds
# Frame 31: Processing time = 0.01 seconds
# Frame 32: Processing time = 0.01 seconds
# Frame 33: Processing time = 0.01 seconds
# Frame 34: Processing time = 0.01 seconds
# Frame 35: Processing time = 0.01 seconds
# Frame 36: Processing time = 0.01 seconds
# Frame 37: Processing time = 0.01 seconds
# Frame 38: Processing time = 0.01 seconds
# Frame 39: Processing time = 0.01 seconds
# Frame 40: Processing time = 0.01 seconds
# Frame 41: Processing time = 0.01 seconds
# Frame 42: Processing time = 0.01 seconds
# Frame 43: Processing time = 0.01 seconds
# Frame 44: Processing time = 0.01 seconds
# Frame 45: Processing time = 0.01 seconds
# Frame 46: Processing time = 0.01 seconds
# Frame 47: Processing time = 0.01 seconds
# Frame 48: Processing time = 0.01 seconds
# Frame 49: Processing time = 0.01 seconds
# Frame 50: Processing time = 0.01 seconds
# Frame 51: Processing time = 0.01 seconds
# Frame 52: Processing time = 0.01 seconds
# Frame 53: Processing time = 0.01 seconds
# Frame 54: Processing time = 0.01 seconds
# Frame 55: Processing time = 0.01 seconds
# Frame 56: Processing time = 0.01 seconds
# Frame 57: Processing time = 0.01 seconds
# Frame 58: Processing time = 0.01 seconds
# Frame 59: Processing time = 0.01 seconds
# Frame 60: Processing time = 0.01 seconds
# Frame 61: Processing time = 0.01 seconds
# Frame 62: Processing time = 0.01 seconds
# Frame 63: Processing time = 0.01 seconds
# Frame 64: Processing time = 0.01 seconds
# Frame 65: Processing time = 0.01 seconds
# Frame 66: Processing time = 0.01 seconds
# Frame 67: Processing time = 0.01 seconds
# Frame 68: Processing time = 0.01 seconds
# Frame 69: Processing time = 0.01 seconds
# Frame 70: Processing time = 0.01 seconds
# Frame 71: Processing time = 0.01 seconds
# Frame 72: Processing time = 0.01 seconds
# Frame 73: Processing time = 0.01 seconds
# Frame 74: Processing time = 0.01 seconds
# Frame 75: Processing time = 0.01 seconds
# Frame 76: Processing time = 0.01 seconds
# Frame 77: Processing time = 0.01 seconds
# Frame 78: Processing time = 0.01 seconds
# Frame 79: Processing time = 0.01 seconds
# Frame 80: Processing time = 0.01 seconds
# Frame 81: Processing time = 0.01 seconds
# Frame 82: Processing time = 0.01 seconds
# Frame 83: Processing time = 0.01 seconds
# Frame 84: Processing time = 0.01 seconds
# Frame 85: Processing time = 0.01 seconds
# Frame 86: Processing time = 0.01 seconds
# Frame 87: Processing time = 0.01 seconds
# Frame 88: Processing time = 0.01 seconds
# Frame 89: Processing time = 0.01 seconds
# Frame 90: Processing time = 0.01 seconds
# Frame 91: Processing time = 0.01 seconds
# Frame 92: Processing time = 0.01 seconds
# Frame 93: Processing time = 0.01 seconds
# Frame 94: Processing time = 0.01 seconds
# Frame 95: Processing time = 0.01 seconds
# Frame 96: Processing time = 0.01 seconds
# Frame 97: Processing time = 0.01 seconds
# Frame 98: Processing time = 0.01 seconds
# Frame 99: Processing time = 0.01 seconds
# Frame 100: Processing time = 0.01 seconds
# Frame 101: Processing time = 0.01 seconds
# Frame 102: Processing time = 0.01 seconds
# Frame 103: Processing time = 0.01 seconds
# Frame 104: Processing time = 0.01 seconds
# Frame 105: Processing time = 0.01 seconds
# Frame 106: Processing time = 0.01 seconds
# Frame 107: Processing time = 0.01 seconds
# Frame 108: Processing time = 0.01 seconds
# Frame 109: Processing time = 0.01 seconds
# Frame 110: Processing time = 0.01 seconds
# Frame 111: Processing time = 0.01 seconds
# Frame 112: Processing time = 0.01 seconds
# Frame 113: Processing time = 0.01 seconds
# Frame 114: Processing time = 0.01 seconds
# Frame 115: Processing time = 0.01 seconds
# Frame 116: Processing time = 0.01 seconds
# Frame 117: Processing time = 0.01 seconds
# Frame 118: Processing time = 0.01 seconds
# Frame 119: Processing time = 0.02 seconds
# Frame 120: Processing time = 0.02 seconds
# Frame 121: Processing time = 0.01 seconds
# Frame 122: Processing time = 0.01 seconds
# Frame 123: Processing time = 0.01 seconds
# Frame 124: Processing time = 0.01 seconds
# Frame 125: Processing time = 0.01 seconds
# Frame 126: Processing time = 0.01 seconds
# Frame 127: Processing time = 0.01 seconds
# Frame 128: Processing time = 0.01 seconds
# Frame 129: Processing time = 0.01 seconds
# Frame 130: Processing time = 0.01 seconds
# Frame 131: Processing time = 0.01 seconds
# Frame 132: Processing time = 0.01 seconds
# Frame 133: Processing time = 0.01 seconds
# Frame 134: Processing time = 0.01 seconds
# Frame 135: Processing time = 0.01 seconds
# Frame 136: Processing time = 0.01 seconds
# Frame 137: Processing time = 0.01 seconds
# Frame 138: Processing time = 0.01 seconds
# Frame 139: Processing time = 0.01 seconds
# Frame 140: Processing time = 0.01 seconds
# Frame 141: Processing time = 0.01 seconds
# Frame 142: Processing time = 0.01 seconds
# Frame 143: Processing time = 0.01 seconds
# Frame 144: Processing time = 0.01 seconds
# Frame 145: Processing time = 0.01 seconds
# Frame 146: Processing time = 0.01 seconds
# Frame 147: Processing time = 0.01 seconds
# Frame 148: Processing time = 0.01 seconds
# Frame 149: Processing time = 0.01 seconds
# Frame 150: Processing time = 0.01 seconds
# Frame 151: Processing time = 0.01 seconds
# Frame 152: Processing time = 0.01 seconds
# Frame 153: Processing time = 0.01 seconds
# Frame 154: Processing time = 0.01 seconds
# Frame 155: Processing time = 0.01 seconds
# Frame 156: Processing time = 0.01 seconds
# Frame 157: Processing time = 0.01 seconds
# Frame 158: Processing time = 0.01 seconds
# Frame 159: Processing time = 0.01 seconds
# Frame 160: Processing time = 0.01 seconds
# Frame 161: Processing time = 0.01 seconds
# Frame 162: Processing time = 0.01 seconds
# Frame 163: Processing time = 0.01 seconds
# Frame 164: Processing time = 0.01 seconds
# Frame 165: Processing time = 0.01 seconds
# Frame 166: Processing time = 0.01 seconds
# Frame 167: Processing time = 0.01 seconds
# Frame 168: Processing time = 0.01 seconds
# Frame 169: Processing time = 0.01 seconds
# Frame 170: Processing time = 0.01 seconds
# Frame 171: Processing time = 0.01 seconds
# Frame 172: Processing time = 0.01 seconds
# Frame 173: Processing time = 0.01 seconds
# Frame 174: Processing time = 0.01 seconds
# Frame 175: Processing time = 0.01 seconds
# Frame 176: Processing time = 0.01 seconds
# Frame 177: Processing time = 0.01 seconds
# Frame 178: Processing time = 0.01 seconds
# Frame 179: Processing time = 0.01 seconds
# Frame 180: Processing time = 0.01 seconds
# Frame 181: Processing time = 0.01 seconds
# Frame 182: Processing time = 0.01 seconds
# Frame 183: Processing time = 0.01 seconds
# Frame 184: Processing time = 0.01 seconds
# Frame 185: Processing time = 0.01 seconds
# Frame 186: Processing time = 0.01 seconds
# Frame 187: Processing time = 0.01 seconds
# Frame 188: Processing time = 0.01 seconds
# Frame 189: Processing time = 0.01 seconds
# Frame 190: Processing time = 0.01 seconds
# Frame 191: Processing time = 0.01 seconds
# Frame 192: Processing time = 0.01 seconds
# Frame 193: Processing time = 0.01 seconds
# Frame 194: Processing time = 0.00 seconds
# Frame 195: Processing time = 0.01 seconds
# Frame 196: Processing time = 0.01 seconds
# Frame 197: Processing time = 0.00 seconds
# Frame 198: Processing time = 0.01 seconds
# Frame 199: Processing time = 0.01 seconds
# Frame 200: Processing time = 0.01 seconds
# Frame 201: Processing time = 0.01 seconds
# Frame 202: Processing time = 0.01 seconds
# Frame 203: Processing time = 0.01 seconds
# Frame 204: Processing time = 0.01 seconds
# Frame 205: Processing time = 0.01 seconds
# Frame 206: Processing time = 0.01 seconds
# Frame 207: Processing time = 0.01 seconds
# Frame 208: Processing time = 0.01 seconds
# Frame 209: Processing time = 0.01 seconds
# Frame 210: Processing time = 0.01 seconds
# Frame 211: Processing time = 0.01 seconds
# Frame 212: Processing time = 0.01 seconds
# Frame 213: Processing time = 0.01 seconds
# Frame 214: Processing time = 0.01 seconds
# Frame 215: Processing time = 0.01 seconds
# Frame 216: Processing time = 0.01 seconds
# Frame 217: Processing time = 0.01 seconds
# Frame 218: Processing time = 0.01 seconds
# Frame 219: Processing time = 0.01 seconds
# Frame 220: Processing time = 0.01 seconds
# Frame 221: Processing time = 0.01 seconds
# Frame 222: Processing time = 0.01 seconds
# Frame 223: Processing time = 0.01 seconds
# Frame 224: Processing time = 0.01 seconds
# Frame 225: Processing time = 0.01 seconds
# Frame 226: Processing time = 0.01 seconds
# Frame 227: Processing time = 0.01 seconds
# Frame 228: Processing time = 0.01 seconds
# Frame 229: Processing time = 0.01 seconds
# Frame 230: Processing time = 0.01 seconds
# Frame 231: Processing time = 0.01 seconds
# Frame 232: Processing time = 0.01 seconds
# Frame 233: Processing time = 0.01 seconds
# Frame 234: Processing time = 0.01 seconds
# Frame 235: Processing time = 0.01 seconds
# Frame 236: Processing time = 0.01 seconds
# Frame 237: Processing time = 0.01 seconds
# Frame 238: Processing time = 0.01 seconds
# Frame 239: Processing time = 0.01 seconds
# Frame 240: Processing time = 0.01 seconds
# Frame 241: Processing time = 0.01 seconds
# Frame 242: Processing time = 0.01 seconds
# Frame 243: Processing time = 0.01 seconds
# Frame 244: Processing time = 0.01 seconds
# Frame 245: Processing time = 0.01 seconds
# Frame 246: Processing time = 0.01 seconds
# Frame 247: Processing time = 0.01 seconds
# Frame 248: Processing time = 0.01 seconds
# Frame 249: Processing time = 0.01 seconds
# Frame 250: Processing time = 0.01 seconds
# Frame 251: Processing time = 0.01 seconds
# Frame 252: Processing time = 0.01 seconds
# Frame 253: Processing time = 0.01 seconds
# Frame 254: Processing time = 0.01 seconds
# Frame 255: Processing time = 0.01 seconds
# Frame 256: Processing time = 0.01 seconds
# Frame 257: Processing time = 0.01 seconds
# Frame 258: Processing time = 0.01 seconds
# Frame 259: Processing time = 0.01 seconds
# Frame 260: Processing time = 0.01 seconds
# Frame 261: Processing time = 0.01 seconds
# Frame 262: Processing time = 0.01 seconds
# Frame 263: Processing time = 0.01 seconds
# Frame 264: Processing time = 0.01 seconds
# Frame 265: Processing time = 0.01 seconds
# Frame 266: Processing time = 0.01 seconds
# Frame 267: Processing time = 0.01 seconds
# Frame 268: Processing time = 0.01 seconds
# Frame 269: Processing time = 0.01 seconds
# Frame 270: Processing time = 0.01 seconds
# Frame 271: Processing time = 0.01 seconds
# Frame 272: Processing time = 0.01 seconds
# Frame 273: Processing time = 0.01 seconds
# Frame 274: Processing time = 0.01 seconds
# Frame 275: Processing time = 0.01 seconds
# Frame 276: Processing time = 0.01 seconds
# Frame 277: Processing time = 0.01 seconds
# Frame 278: Processing time = 0.01 seconds
# Frame 279: Processing time = 0.01 seconds
# Frame 280: Processing time = 0.01 seconds
# Frame 281: Processing time = 0.01 seconds
# Frame 282: Processing time = 0.01 seconds
# Frame 283: Processing time = 0.01 seconds
# Frame 284: Processing time = 0.01 seconds
# Frame 285: Processing time = 0.01 seconds
# Frame 286: Processing time = 0.01 seconds
# Frame 287: Processing time = 0.01 seconds
# Frame 288: Processing time = 0.01 seconds
# Frame 289: Processing time = 0.01 seconds
# Frame 290: Processing time = 0.01 seconds
# Frame 291: Processing time = 0.01 seconds
# Frame 292: Processing time = 0.01 seconds
# Frame 293: Processing time = 0.01 seconds
# Frame 294: Processing time = 0.01 seconds
# Frame 295: Processing time = 0.01 seconds
# Frame 296: Processing time = 0.01 seconds
# Frame 297: Processing time = 0.01 seconds
# Frame 298: Processing time = 0.01 seconds
# Frame 299: Processing time = 0.01 seconds
# Frame 300: Processing time = 0.01 seconds
# Frame 301: Processing time = 0.01 seconds
# Frame 302: Processing time = 0.01 seconds
# Frame 303: Processing time = 0.01 seconds
# Frame 304: Processing time = 0.01 seconds
# Frame 305: Processing time = 0.01 seconds
# Frame 306: Processing time = 0.01 seconds
# Frame 307: Processing time = 0.01 seconds
# Frame 308: Processing time = 0.01 seconds
# Frame 309: Processing time = 0.01 seconds
# Frame 310: Processing time = 0.01 seconds
# Frame 311: Processing time = 0.01 seconds
# Frame 312: Processing time = 0.01 seconds
# Frame 313: Processing time = 0.01 seconds
# Frame 314: Processing time = 0.01 seconds
# Frame 315: Processing time = 0.02 seconds
# Frame 316: Processing time = 0.01 seconds
# Frame 317: Processing time = 0.01 seconds
# Frame 318: Processing time = 0.01 seconds
# Frame 319: Processing time = 0.01 seconds
# Frame 320: Processing time = 0.01 seconds
# Frame 321: Processing time = 0.01 seconds
# Frame 322: Processing time = 0.01 seconds
# Frame 323: Processing time = 0.01 seconds
# Frame 324: Processing time = 0.01 seconds
# Frame 325: Processing time = 0.01 seconds
# Frame 326: Processing time = 0.01 seconds
# Frame 327: Processing time = 0.01 seconds
# Frame 328: Processing time = 0.01 seconds
# Frame 329: Processing time = 0.01 seconds
# Frame 330: Processing time = 0.01 seconds
# Frame 331: Processing time = 0.01 seconds
# Frame 332: Processing time = 0.01 seconds
# Frame 333: Processing time = 0.01 seconds
# Frame 334: Processing time = 0.01 seconds
# Frame 335: Processing time = 0.01 seconds
# Frame 336: Processing time = 0.01 seconds
# Frame 337: Processing time = 0.01 seconds
# Frame 338: Processing time = 0.01 seconds
# Frame 339: Processing time = 0.01 seconds
# Frame 340: Processing time = 0.01 seconds
# Frame 341: Processing time = 0.01 seconds
# Frame 342: Processing time = 0.01 seconds
# Frame 343: Processing time = 0.01 seconds
# Frame 344: Processing time = 0.01 seconds
# Frame 345: Processing time = 0.01 seconds
# Frame 346: Processing time = 0.01 seconds
# Frame 347: Processing time = 0.01 seconds
# Frame 348: Processing time = 0.01 seconds
# Frame 349: Processing time = 0.01 seconds
# Frame 350: Processing time = 0.01 seconds
# Frame 351: Processing time = 0.01 seconds
# Frame 352: Processing time = 0.01 seconds
# Frame 353: Processing time = 0.01 seconds
# Frame 354: Processing time = 0.01 seconds
# Frame 355: Processing time = 0.01 seconds
# Frame 356: Processing time = 0.01 seconds
# Frame 357: Processing time = 0.01 seconds
# Frame 358: Processing time = 0.01 seconds
# Frame 359: Processing time = 0.01 seconds
# Frame 360: Processing time = 0.01 seconds
# Frame 361: Processing time = 0.01 seconds
# Frame 362: Processing time = 0.01 seconds
# Frame 363: Processing time = 0.01 seconds
# Frame 364: Processing time = 0.01 seconds
# Frame 365: Processing time = 0.01 seconds
# Frame 366: Processing time = 0.01 seconds
# Frame 367: Processing time = 0.01 seconds
# Frame 368: Processing time = 0.01 seconds
# Frame 369: Processing time = 0.01 seconds
# Frame 370: Processing time = 0.01 seconds
# Frame 371: Processing time = 0.01 seconds
# Frame 372: Processing time = 0.01 seconds
# Frame 373: Processing time = 0.01 seconds
# Frame 374: Processing time = 0.01 seconds
# Frame 375: Processing time = 0.01 seconds
# Frame 376: Processing time = 0.01 seconds
# Frame 377: Processing time = 0.01 seconds
# Frame 378: Processing time = 0.01 seconds
# Frame 379: Processing time = 0.01 seconds
# Frame 380: Processing time = 0.01 seconds
# Frame 381: Processing time = 0.01 seconds
# Frame 382: Processing time = 0.01 seconds
# Frame 383: Processing time = 0.01 seconds
# Frame 384: Processing time = 0.01 seconds
# Frame 385: Processing time = 0.01 seconds
# Frame 386: Processing time = 0.01 seconds
# Frame 387: Processing time = 0.01 seconds
# Frame 388: Processing time = 0.01 seconds
# Frame 389: Processing time = 0.01 seconds
# Frame 390: Processing time = 0.01 seconds
# Frame 391: Processing time = 0.01 seconds
# Frame 392: Processing time = 0.01 seconds
# Frame 393: Processing time = 0.01 seconds
# Frame 394: Processing time = 0.01 seconds
# Frame 395: Processing time = 0.01 seconds
# Frame 396: Processing time = 0.01 seconds
# Frame 397: Processing time = 0.01 seconds
# Frame 398: Processing time = 0.01 seconds
# Frame 399: Processing time = 0.01 seconds
# Frame 400: Processing time = 0.01 seconds
# Frame 401: Processing time = 0.01 seconds
# Frame 402: Processing time = 0.01 seconds
# Frame 403: Processing time = 0.01 seconds
# Frame 404: Processing time = 0.01 seconds
# Frame 405: Processing time = 0.01 seconds
# Frame 406: Processing time = 0.01 seconds
# Frame 407: Processing time = 0.01 seconds
# Frame 408: Processing time = 0.01 seconds
# Frame 409: Processing time = 0.01 seconds
# Frame 410: Processing time = 0.01 seconds
# Frame 411: Processing time = 0.01 seconds
# Frame 412: Processing time = 0.01 seconds
# Frame 413: Processing time = 0.01 seconds
# Frame 414: Processing time = 0.01 seconds
# Frame 415: Processing time = 0.01 seconds
# Frame 416: Processing time = 0.01 seconds
# Frame 417: Processing time = 0.01 seconds
# Frame 418: Processing time = 0.01 seconds
# Frame 419: Processing time = 0.01 seconds
# Frame 420: Processing time = 0.01 seconds
# Frame 421: Processing time = 0.01 seconds
# Frame 422: Processing time = 0.01 seconds
# Frame 423: Processing time = 0.01 seconds
# Frame 424: Processing time = 0.01 seconds
# Frame 425: Processing time = 0.01 seconds
# Frame 426: Processing time = 0.01 seconds
# Frame 427: Processing time = 0.01 seconds
# Frame 428: Processing time = 0.01 seconds
# Frame 429: Processing time = 0.01 seconds
# Frame 430: Processing time = 0.01 seconds
# Frame 431: Processing time = 0.01 seconds
# Frame 432: Processing time = 0.01 seconds
# Frame 433: Processing time = 0.01 seconds
# Frame 434: Processing time = 0.01 seconds
# Frame 435: Processing time = 0.01 seconds
# Frame 436: Processing time = 0.01 seconds
# Frame 437: Processing time = 0.01 seconds
# Frame 438: Processing time = 0.01 seconds
# Frame 439: Processing time = 0.01 seconds
# Frame 440: Processing time = 0.01 seconds
# Frame 441: Processing time = 0.01 seconds
# Frame 442: Processing time = 0.01 seconds
# Frame 443: Processing time = 0.01 seconds
# Frame 444: Processing time = 0.01 seconds
# Frame 445: Processing time = 0.01 seconds
# Frame 446: Processing time = 0.01 seconds
# Frame 447: Processing time = 0.01 seconds
# Frame 448: Processing time = 0.01 seconds
# Frame 449: Processing time = 0.01 seconds
# Frame 450: Processing time = 0.01 seconds
# Frame 451: Processing time = 0.01 seconds
# Frame 452: Processing time = 0.01 seconds
# Frame 453: Processing time = 0.01 seconds
# Frame 454: Processing time = 0.01 seconds
# Frame 455: Processing time = 0.01 seconds
# Frame 456: Processing time = 0.01 seconds
# Frame 457: Processing time = 0.01 seconds
# Frame 458: Processing time = 0.01 seconds
# Frame 459: Processing time = 0.01 seconds
# Frame 460: Processing time = 0.01 seconds
# Frame 461: Processing time = 0.01 seconds
# Frame 462: Processing time = 0.01 seconds
# Frame 463: Processing time = 0.01 seconds
# Frame 464: Processing time = 0.01 seconds
# Frame 465: Processing time = 0.01 seconds
# Frame 466: Processing time = 0.01 seconds
# Frame 467: Processing time = 0.01 seconds
# Frame 468: Processing time = 0.01 seconds
# Frame 469: Processing time = 0.01 seconds
# Frame 470: Processing time = 0.01 seconds
# Frame 471: Processing time = 0.01 seconds
# Frame 472: Processing time = 0.01 seconds
# Frame 473: Processing time = 0.01 seconds
# Frame 474: Processing time = 0.01 seconds
# Frame 475: Processing time = 0.01 seconds
# Frame 476: Processing time = 0.01 seconds
# Frame 477: Processing time = 0.01 seconds
# Frame 478: Processing time = 0.01 seconds
# Frame 479: Processing time = 0.01 seconds
# Frame 480: Processing time = 0.01 seconds
# Frame 481: Processing time = 0.01 seconds
# Frame 482: Processing time = 0.01 seconds
# Frame 483: Processing time = 0.01 seconds
# Frame 484: Processing time = 0.01 seconds
# Frame 485: Processing time = 0.01 seconds
# Frame 486: Processing time = 0.01 seconds
# Frame 487: Processing time = 0.01 seconds
# Frame 488: Processing time = 0.01 seconds
# Frame 489: Processing time = 0.01 seconds
# Frame 490: Processing time = 0.01 seconds
# Frame 491: Processing time = 0.01 seconds
# Frame 492: Processing time = 0.01 seconds
# Frame 493: Processing time = 0.01 seconds
# Frame 494: Processing time = 0.01 seconds
# Frame 495: Processing time = 0.01 seconds
# Frame 496: Processing time = 0.01 seconds
# Frame 497: Processing time = 0.01 seconds
# Frame 498: Processing time = 0.01 seconds
# Frame 499: Processing time = 0.01 seconds
# Frame 500: Processing time = 0.01 seconds
# Frame 501: Processing time = 0.01 seconds
# Frame 502: Processing time = 0.01 seconds
# Frame 503: Processing time = 0.01 seconds
# Frame 504: Processing time = 0.01 seconds
# Frame 505: Processing time = 0.01 seconds
# Frame 506: Processing time = 0.01 seconds
# Frame 507: Processing time = 0.01 seconds
# Frame 508: Processing time = 0.01 seconds
# Frame 509: Processing time = 0.01 seconds
# Frame 510: Processing time = 0.01 seconds
# Frame 511: Processing time = 0.01 seconds
# Frame 512: Processing time = 0.01 seconds
# Frame 513: Processing time = 0.01 seconds
# Frame 514: Processing time = 0.01 seconds
# Frame 515: Processing time = 0.01 seconds
# Frame 516: Processing time = 0.01 seconds
# Frame 517: Processing time = 0.01 seconds
# Frame 518: Processing time = 0.01 seconds
# Frame 519: Processing time = 0.01 seconds
# Frame 520: Processing time = 0.01 seconds
# Frame 521: Processing time = 0.01 seconds
# Frame 522: Processing time = 0.01 seconds
# Frame 523: Processing time = 0.01 seconds
# Frame 524: Processing time = 0.01 seconds
# Frame 525: Processing time = 0.01 seconds
# Frame 526: Processing time = 0.01 seconds
# Frame 527: Processing time = 0.01 seconds
# Frame 528: Processing time = 0.01 seconds
# Frame 529: Processing time = 0.01 seconds
# Frame 530: Processing time = 0.01 seconds
# Frame 531: Processing time = 0.01 seconds
# Frame 532: Processing time = 0.01 seconds
# Frame 533: Processing time = 0.01 seconds
# Frame 534: Processing time = 0.01 seconds
# Frame 535: Processing time = 0.01 seconds
# Frame 536: Processing time = 0.01 seconds
# Frame 537: Processing time = 0.01 seconds
# Frame 538: Processing time = 0.01 seconds
# Frame 539: Processing time = 0.01 seconds
# Frame 540: Processing time = 0.01 seconds
# Frame 541: Processing time = 0.01 seconds
# Frame 542: Processing time = 0.01 seconds
# Frame 543: Processing time = 0.01 seconds
# Frame 544: Processing time = 0.01 seconds
# Frame 545: Processing time = 0.01 seconds
# Frame 546: Processing time = 0.01 seconds
# Frame 547: Processing time = 0.01 seconds
# Frame 548: Processing time = 0.01 seconds
# Frame 549: Processing time = 0.01 seconds
# Frame 550: Processing time = 0.01 seconds
# Frame 551: Processing time = 0.01 seconds
# Frame 552: Processing time = 0.01 seconds
# Frame 553: Processing time = 0.01 seconds
# Frame 554: Processing time = 0.01 seconds
# Frame 555: Processing time = 0.01 seconds
# Frame 556: Processing time = 0.01 seconds
# Frame 557: Processing time = 0.01 seconds
# Frame 558: Processing time = 0.01 seconds
# Frame 559: Processing time = 0.01 seconds
# Frame 560: Processing time = 0.01 seconds
# Frame 561: Processing time = 0.01 seconds
# Frame 562: Processing time = 0.01 seconds
# Frame 563: Processing time = 0.01 seconds
# Frame 564: Processing time = 0.01 seconds
# Frame 565: Processing time = 0.01 seconds
# Frame 566: Processing time = 0.01 seconds
# Frame 567: Processing time = 0.01 seconds
# Frame 568: Processing time = 0.01 seconds
# Frame 569: Processing time = 0.01 seconds
# Frame 570: Processing time = 0.01 seconds
# Frame 571: Processing time = 0.01 seconds
# Frame 572: Processing time = 0.01 seconds
# Frame 573: Processing time = 0.01 seconds
# Frame 574: Processing time = 0.01 seconds
# Frame 575: Processing time = 0.01 seconds
# Frame 576: Processing time = 0.01 seconds
# Frame 577: Processing time = 0.01 seconds
# Frame 578: Processing time = 0.01 seconds
# Frame 579: Processing time = 0.01 seconds
# Frame 580: Processing time = 0.01 seconds
# Frame 581: Processing time = 0.01 seconds
# Frame 582: Processing time = 0.01 seconds
# Frame 583: Processing time = 0.01 seconds
# Frame 584: Processing time = 0.01 seconds
# Frame 585: Processing time = 0.01 seconds
# Frame 586: Processing time = 0.01 seconds
# Frame 587: Processing time = 0.01 seconds
# Frame 588: Processing time = 0.01 seconds
# Frame 589: Processing time = 0.01 seconds
# Frame 590: Processing time = 0.01 seconds
# Frame 591: Processing time = 0.01 seconds
# Frame 592: Processing time = 0.01 seconds
# Frame 593: Processing time = 0.01 seconds
# Frame 594: Processing time = 0.01 seconds
# Frame 595: Processing time = 0.01 seconds
# Frame 596: Processing time = 0.01 seconds
# Frame 597: Processing time = 0.01 seconds
# Frame 598: Processing time = 0.01 seconds
# Frame 599: Processing time = 0.01 seconds
# Frame 600: Processing time = 0.01 seconds
# Frame 601: Processing time = 0.01 seconds
# Frame 602: Processing time = 0.01 seconds
# Frame 603: Processing time = 0.01 seconds
# Frame 604: Processing time = 0.01 seconds
# Frame 605: Processing time = 0.01 seconds
# Frame 606: Processing time = 0.01 seconds
# Frame 607: Processing time = 0.01 seconds
# Frame 608: Processing time = 0.01 seconds
# Frame 609: Processing time = 0.01 seconds
# Frame 610: Processing time = 0.01 seconds
# Frame 611: Processing time = 0.01 seconds
# Frame 612: Processing time = 0.01 seconds
# Frame 613: Processing time = 0.01 seconds
# Frame 614: Processing time = 0.01 seconds
# Frame 615: Processing time = 0.01 seconds
# Frame 616: Processing time = 0.01 seconds
# Frame 617: Processing time = 0.01 seconds
# Frame 618: Processing time = 0.01 seconds
# Frame 619: Processing time = 0.01 seconds
# Frame 620: Processing time = 0.01 seconds
# Frame 621: Processing time = 0.01 seconds
# Frame 622: Processing time = 0.01 seconds
# Frame 623: Processing time = 0.01 seconds
# Frame 624: Processing time = 0.01 seconds
# Frame 625: Processing time = 0.01 seconds
# Frame 626: Processing time = 0.01 seconds
# Frame 627: Processing time = 0.01 seconds
# Frame 628: Processing time = 0.01 seconds
# Frame 629: Processing time = 0.01 seconds
# Frame 630: Processing time = 0.01 seconds
# Frame 631: Processing time = 0.01 seconds
# Frame 632: Processing time = 0.01 seconds
# Frame 633: Processing time = 0.01 seconds
# Frame 634: Processing time = 0.01 seconds
# Frame 635: Processing time = 0.01 seconds
# Frame 636: Processing time = 0.01 seconds
# Frame 637: Processing time = 0.01 seconds
# Frame 638: Processing time = 0.01 seconds
# Frame 639: Processing time = 0.01 seconds
# Frame 640: Processing time = 0.01 seconds
# Frame 641: Processing time = 0.01 seconds
# Frame 642: Processing time = 0.01 seconds
# Frame 643: Processing time = 0.01 seconds
# Frame 644: Processing time = 0.01 seconds
# Frame 645: Processing time = 0.01 seconds
# Frame 646: Processing time = 0.01 seconds
# Frame 647: Processing time = 0.01 seconds
# Frame 648: Processing time = 0.01 seconds
# Frame 649: Processing time = 0.01 seconds
# Frame 650: Processing time = 0.01 seconds
# Frame 651: Processing time = 0.01 seconds
# Frame 652: Processing time = 0.01 seconds
# Frame 653: Processing time = 0.01 seconds
# Frame 654: Processing time = 0.01 seconds
# Frame 655: Processing time = 0.01 seconds
# Frame 656: Processing time = 0.01 seconds
# Frame 657: Processing time = 0.01 seconds
# Frame 658: Processing time = 0.01 seconds
# Frame 659: Processing time = 0.01 seconds
# Frame 660: Processing time = 0.01 seconds
# Frame 661: Processing time = 0.01 seconds
# Frame 662: Processing time = 0.01 seconds
# Frame 663: Processing time = 0.01 seconds
# Frame 664: Processing time = 0.01 seconds
# Frame 665: Processing time = 0.01 seconds
# Frame 666: Processing time = 0.01 seconds
# Frame 667: Processing time = 0.01 seconds
# Frame 668: Processing time = 0.01 seconds
# Frame 669: Processing time = 0.01 seconds
# Frame 670: Processing time = 0.01 seconds
# Frame 671: Processing time = 0.01 seconds
# Frame 672: Processing time = 0.01 seconds
# Frame 673: Processing time = 0.01 seconds
# Frame 674: Processing time = 0.01 seconds
# Frame 675: Processing time = 0.01 seconds
# Frame 676: Processing time = 0.01 seconds
# Frame 677: Processing time = 0.01 seconds
# Frame 678: Processing time = 0.01 seconds
# Frame 679: Processing time = 0.01 seconds
# Frame 680: Processing time = 0.01 seconds
# Frame 681: Processing time = 0.01 seconds
# Frame 682: Processing time = 0.01 seconds
# Frame 683: Processing time = 0.01 seconds
# Frame 684: Processing time = 0.01 seconds
# Frame 685: Processing time = 0.01 seconds
# Frame 686: Processing time = 0.01 seconds
# Frame 687: Processing time = 0.01 seconds
# Frame 688: Processing time = 0.01 seconds
# Frame 689: Processing time = 0.01 seconds
# Frame 690: Processing time = 0.01 seconds
# Frame 691: Processing time = 0.01 seconds
# Frame 692: Processing time = 0.01 seconds
# Frame 693: Processing time = 0.01 seconds
# Frame 694: Processing time = 0.01 seconds
# Frame 695: Processing time = 0.01 seconds
# Frame 696: Processing time = 0.01 seconds
# Frame 697: Processing time = 0.01 seconds
# Frame 698: Processing time = 0.01 seconds
# Frame 699: Processing time = 0.01 seconds
# Frame 700: Processing time = 0.01 seconds
# Frame 701: Processing time = 0.01 seconds
# Frame 702: Processing time = 0.01 seconds
# Frame 703: Processing time = 0.01 seconds
# Frame 704: Processing time = 0.01 seconds
# Frame 705: Processing time = 0.01 seconds
# Frame 706: Processing time = 0.01 seconds
# Frame 707: Processing time = 0.01 seconds
# Frame 708: Processing time = 0.01 seconds
# Frame 709: Processing time = 0.01 seconds
# Frame 710: Processing time = 0.01 seconds
# Frame 711: Processing time = 0.01 seconds
# Frame 712: Processing time = 0.01 seconds
# Frame 713: Processing time = 0.01 seconds
# Frame 714: Processing time = 0.01 seconds
# Frame 715: Processing time = 0.01 seconds
# Frame 716: Processing time = 0.01 seconds
# Frame 717: Processing time = 0.01 seconds
# Frame 718: Processing time = 0.01 seconds
# Frame 719: Processing time = 0.01 seconds
# Frame 720: Processing time = 0.01 seconds
# Total processing time for all frames: 7.79 seconds

# %% [markdown]
# #### After experimenting with different parameter values for the face detection algorithm, I found that adjusting the following parameters led to a reduction in processing time:
#
# - **Scale Factor:** I tried different scale factors, including 1.1, 1.3, 1.8, and 2.2. By increasing the scale factor, I observed a decrease in processing time, with a scale factor of 1.3 providing the best balance between accuracy and speed.
#
# - **MinNeighbors:** I varied the number of neighbors for each candidate rectangle, testing values such as 5, 8, and 10. Increasing the minNeighbors parameter can reduce false positives but may also slow down the detection process. I found that setting minNeighbors to 8 resulted in a significant reduction in processing time while maintaining satisfactory detection accuracy.
#
# - **MinSize:** Adjusting the minimum object size parameter, I experimented with values such as (10, 10), (15, 15), (25, 25), and (30, 30). Decreasing the minSize parameter may increase false positives and processing time, while increasing it may reduce the likelihood of false positives but may also lead to missed detections. I found that a minimum size of (15, 15) provided a good balance between speed and accuracy.
#
# With the optimized parameter values, I observed a reduction in processing time from an average of 0.02 to 0.04 seconds per frame to approximately 0.01 seconds per frame on average. These optimizations allow for efficient face detection while maintaining satisfactory detection accuracy.

# %% [markdown]
# ## 1.3 - Face detection visualization.
# Visualize the face detections made over the first 30s frames as a new video. Link to the video from your google drive. Watch the video and draw three conclusions about when does the face detector work or fail. Why do you think this is the case?
# Hint: You can use cv2.rectangle to draw boxes on the image and then save them back to disk. Then ffmpeg can be used again to stitch together the frames into a new video.

# %% [markdown]
# ### Observations on Face Detection Video
#
# After watching the video created from the face detection process, I made the following observations:
#
# 1. **Successful Face Detection**: In most frames of the 30-second video, the face detector successfully detects and draws rectangles around the faces present in the scene. This indicates that the face detection algorithm is generally effective in identifying faces when they are well-lit, frontal, and of adequate size.
#
# 2. **Undetected Faces**: However, there are instances where some faces in certain frames are not detected by the face detector. This could be due to various reasons, such as:
#    - **Min Frame Size**: The faces that are not detected may be too small in size relative to the minimum size parameter set for the face detection algorithm. This could cause the detector to miss smaller faces or faces that appear farther away in the scene.
#    - **Angles of Faces**: Faces that are not facing directly towards the camera or are at extreme angles may not be detected accurately. The face detector may struggle to identify faces that are tilted or rotated away from the frontal view.
#    - **False Positives**: On the other hand, there are instances where false positive detections occur, resulting in rectangles being drawn around non-facial objects or patterns that resemble faces. This could be due to factors such as shadows, reflections, or patterns that resemble facial features.
#
# 3. **Overall Performance**: Despite these occasional failures, the face detector performs reasonably well in detecting faces across the video frames. It demonstrates the capability to identify faces in a variety of contexts, lighting conditions, and orientations. However, there is room for improvement, especially in handling smaller faces and reducing false positive detections.
#
# Overall, the effectiveness of the face detector is influenced by factors such as the size of the faces, their orientation relative to the camera, and the presence of other objects that may resemble faces. Fine-tuning the parameters of the face detection algorithm and employing additional techniques such as deep learning-based approaches could further enhance its performance.

# %% [markdown]
# ## 1.4 - Association-based tracking.
# Tracking can be used to associate face detections across time and understand that it is the same character appearing across multiple frames of the movie. We will explore a simple way to perform tracking.

# %% [markdown]
# ### 1.4.1 Generate face tracks by comparing face detections in two consecutive frames and associating them based on IoU scores.
# You may want to associate faces only when IoU > 0.5. Do consider what happens when there are multiple face detections in both frames. Start new tracks for faces not seen in the previous frame. End existing tracks when faces are not visible in the next frame. How many unique tracks did you create in the first 30 seconds?

# %%
import cv2
import os

def detect_faces(frame):
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray_frame, scaleFactor=1.3, minNeighbors=8, minSize=(15, 15))
    return faces

def compute_iou(box1, box2):
    x1 = max(box1[0], box2[0])
    y1 = max(box1[1], box2[1])
    x2 = min(box1[0] + box1[2], box2[0] + box2[2])
    y2 = min(box1[1] + box1[3], box2[1] + box2[3])
    intersection_area = max(0, x2 - x1 + 1) * max(0, y2 - y1 + 1)
    box1_area = (box1[2] + 1) * (box1[3] + 1)
    box2_area = (box2[2] + 1) * (box2[3] + 1)
    iou = intersection_area / float(box1_area + box2_area - intersection_area)
    return iou

def associate_face_tracks(frames_folder):
    tracks = {}
    output_folder = "output"
    output_video_name = "tracked_output.mp4"
    output_video_path = os.path.join(output_folder, output_video_name)
    
    # Get information about the first frame
    frame_path = os.path.join(frames_folder, "frame_001.png")
    first_frame = cv2.imread(frame_path)
    height, width, _ = first_frame.shape
    
    # Define the codec and create VideoWriter object
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_video_path, fourcc, 24.0, (width, height))
    
    track_id = 1  # Initialize track id
    
    for i in range(1, len(os.listdir(frames_folder))):  # Loop through frames
        frame_path = os.path.join(frames_folder, f"frame_{i:03d}.png")
        frame = cv2.imread(frame_path)

        curr_faces = detect_faces(frame)

        # Get faces in the next frame
        next_frame_path = os.path.join(frames_folder, f"frame_{(i+1):03d}.png")
        next_frame = cv2.imread(next_frame_path)
        next_faces = detect_faces(next_frame)

        # Store matching tracks for current frame
        matched_tracks = {}
        
        # Associate faces with tracks
        for face1 in next_faces :
            for face2 in curr_faces:
                if compute_iou(face1, face2) > 0.5:  
                    if tuple(face2) in tracks.values():
                        for key, value in tracks.items():
                            if value == tuple(face2):
                                tracks[key] = tuple(face1)
                                matched_tracks[tuple(face2)] = key
                    else:
                        matched_tracks[tuple(face2)] = track_id
                        tracks[track_id] = tuple(face1)
                        track_id += 1

        # Draw faces and write track IDs on the frame
        for (x, y, w, h) in curr_faces:
            cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)
            cv2.putText(frame, str(matched_tracks.get(tuple((x, y, w, h)), '')), (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

        out.write(frame)

    
    out.release()
    print("Tracked video saved successfully!")

# %%
frames_folder = "input_frames"
associate_face_tracks(frames_folder)
# Out:
# Tracked video saved successfully!
